# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

import numpy as np
from plotnine import *
import re
import folium
import matplotlib.pyplot as plt 
import seaborn as sns

df_gwangju =  pd.read_csv('/Users/munchoo-kim/Downloads/소상공인시장진흥공단_상가(상권)정보_20230930/소상공인시장진흥공단_상가(상권)정보_광주_202309.csv', encoding='UTF-8')

# %%
df_gwangju.isnull().sum()

import missingno as msno

sns.set(font="AppleGothic", 
        rc={"axes.unicode_minus":False})
msno.matrix(df_gwangju) # 결측치를 확인하고싶은 데이터프레임을 인자로 넣어준다.
# %config InlineBackend.figure_format = 'retina'

plt.show()
