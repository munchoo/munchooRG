# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Apply the default theme
sns.set_theme()

# Load an example dataset
tips = sns.load_dataset("tips")

# Create a visualization
sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",
)

# %%
dots = sns.load_dataset("dots")
sns.relplot(
    data=dots, kind="line",
    x="time", y="firing_rate", col="align",
    hue="choice", size="coherence", style="choice",
    facet_kws=dict(sharex=False),
)

# %%
index = pd.date_range("1 1 2000", periods=100, freq="m", name="date")
data = np.random.randn(100, 4).cumsum(axis=0)
wide_df = pd.DataFrame(data, index, ["a", "b", "c", "d"])
sns.scatterplot(data=wide_df)
# Out:
# <AxesSubplot:xlabel='date'>

# %%
test = pd.read_excel('./dataset/4RGN_MBO_DAILY.xlsx')
test.head()
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#       Datecd                 Team Ln                      Part Ln Storecd  \
# 0 2022-07-01  4부문)3지역)신규점팀            김경열                           8M82
# 1 2022-07-01  4부문)3지역)신규점팀            김경열                           8M82
# 2 2022-07-01  4부문)3지역)신규점팀            김경열                           8M82
# 3 2022-07-01  4부문)3지역)신규점팀            김경열                           8M82
# 4 2022-07-01  4부문)3지역)신규점팀            김경열                           8M82
#
#   Storenm Ntsal Gbnm  메트릭   매출목표  Ntsal Amt
# 0  운암메가씨티     CAFE25  NaN   7500          0
# 1  운암메가씨티        F/F  NaN  69000      41897
# 2  운암메가씨티        고객수  NaN    215        214
# 3  운암메가씨티      냉장/냉동  NaN  21000       7817
# 4  운암메가씨티   농/축/수산식품  NaN   5300      12728

# %%
test['Storecd'] = ('V'+test['Storecd'])

# %%
plt.rcParams['font.family'] = 'NanumGothic'
sns.relplot(data=test, x='일매출달성률\n95%이하점',y='CAFE')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_17988/3598499728.py in <module>
#       1 plt.rcParams['font.family'] = 'NanumGothic'
# ----> 2 sns.relplot(data=test, x='일매출달성률\n95%이하점',y='CAFE')
#       3
#       4
#       5
#
# c:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# c:\ProgramData\Anaconda3\lib\site-packages\seaborn\relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, units, **kwargs)
#     945
# ...

# %%
region = pd.read_excel('./dataset/region.xlsx', engine='openpyxl')

# %%
test['Storecd'] = test['Storecd'].str.replace(' ','')
test['Storecd'][2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_2728/3641562725.py in <module>
# ----> 1 test['Storecd'] = test['Storecd'].str.replace(' ','')
#       2 test['Storecd'][2]
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ...

# %%
test3 = test.set_index('Storecd').join(region.set_index('최초점포코드')).iloc[:,[0,1,2,3,4,6,7,15,16]]
test3
# Out:
#           Datecd                  Team Ln                      Part Ln  \
# V1263 2022-07-01  4부문)3지역)영업2팀             김예지
# V1263 2022-07-01  4부문)3지역)영업2팀             김예지
# V1263 2022-07-01  4부문)3지역)영업2팀             김예지
# V1263 2022-07-01  4부문)3지역)영업2팀             김예지
# V1263 2022-07-01  4부문)3지역)영업2팀             김예지
# ...          ...                      ...                          ...
# VY936 2022-07-07  4부문)3지역)영업4팀             정해웅
# VY936 2022-07-07  4부문)3지역)영업4팀             정해웅
# VY936 2022-07-07  4부문)3지역)영업4팀             정해웅
# VY936 2022-07-07  4부문)3지역)영업4팀             정해웅
# VY936 2022-07-07  4부문)3지역)영업4팀             정해웅
#
#       Storenm Ntsal Gbnm     매출목표  Ntsal Amt 행정구역_대 주소.2.1
# V1263    광주GS        F/F    34000      46274     광주     동구
# V1263    광주GS        고객수      452        720     광주     동구
# V1263    광주GS      냉장/냉동    17000      10636     광주     동구
# V1263    광주GS   농/축/수산식품     6500       8400     광주     동구
# ...

# %%
test3
# Out:
#           Datecd                  Team Ln                      Part Ln  \
# V1263 2022-07-01  4부문)3지역)영업2팀             김예지
# V1263 2022-07-01  4부문)3지역)영업2팀             김예지
# V1263 2022-07-01  4부문)3지역)영업2팀             김예지
# V1263 2022-07-01  4부문)3지역)영업2팀             김예지
# V1263 2022-07-01  4부문)3지역)영업2팀             김예지
# ...          ...                      ...                          ...
# VY936 2022-07-07  4부문)3지역)영업4팀             정해웅
# VY936 2022-07-07  4부문)3지역)영업4팀             정해웅
# VY936 2022-07-07  4부문)3지역)영업4팀             정해웅
# VY936 2022-07-07  4부문)3지역)영업4팀             정해웅
# VY936 2022-07-07  4부문)3지역)영업4팀             정해웅
#
#       Storenm Ntsal Gbnm     매출목표  Ntsal Amt 행정구역_대 주소.2.1
# V1263    광주GS        F/F    34000      46274     광주     동구
# V1263    광주GS        고객수      452        720     광주     동구
# V1263    광주GS      냉장/냉동    17000      10636     광주     동구
# V1263    광주GS   농/축/수산식품     6500       8400     광주     동구
# ...

# %%
g = test.groupby(['Team Ln','Part Ln'])[['매출목표','Ntsal Amt']].mean()

# %%
g = test.groupby('Team Ln')['Part Ln'].nunique()
gg = test.groupby('Team Ln')['Storenm'].nunique()

ggg = pd.concat([g,gg],axis=1)
ggg.rename(columns={'Storenm':'점포수'}, inplace=True)
ggg.reset_index
#m = test.groupby['매출목표'].mean()
#m
ggg['인당평균점포'] = ggg['점포수'] / ggg['Part Ln']

# %%
ages = ggg['점포수']
rev_ages = ages.sort_index(ascending=False)
rev_ages
# Out:
# Team Ln
# 4부문)3지역)영업6팀               107
# 4부문)3지역)영업5팀               114
# 4부문)3지역)영업4팀               112
# 4부문)3지역)영업3팀               119
# 4부문)3지역)영업2팀               115
# 4부문)3지역)영업1팀               111
# 4부문)3지역)신규점팀                24
# Name: 점포수, dtype: int64

# %%
print(ggg[ggg['점포수']>ggg['점포수'].mean()])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_17988/3347149330.py in <module>
# ----> 1 print(ggg[ggg['점포수']>ggg['점포수'].mean()])
#
# NameError: name 'ggg' is not defined

# %%
print(ggg * 1)
# Out:
#                          Part Ln  점포수     인당평균점포
# Team Ln
# 4부문)3지역)신규점팀                   4   24   6.000000
# 4부문)3지역)영업1팀                   8  111  13.875000
# 4부문)3지역)영업2팀                   8  115  14.375000
# 4부문)3지역)영업3팀                   9  119  13.222222
# 4부문)3지역)영업4팀                   8  112  14.000000
# 4부문)3지역)영업5팀                   9  114  12.666667
# 4부문)3지역)영업6팀                   8  107  13.375000

# %%
format_change = pd.to_datetime(test3['Datecd'],format='%yy-%M')
format_change.shape
# Out:
# (40496,)

# %%
import random as rd
rd.seed(42)
ggg['점포수'] = ggg['점포수'].sample(len(ggg['점포수']), random_state=7).reset_index(drop=True)
ggg['점포수']

test['Part Ln'] = test['Part Ln'].str.strip()


test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_17988/2758274305.py in <module>
#       1 import random as rd
#       2 rd.seed(42)
# ----> 3 ggg['점포수'] = ggg['점포수'].sample(len(ggg['점포수']), random_state=7).reset_index(drop=True)
#       4 ggg['점포수']
#       5
#
# NameError: name 'ggg' is not defined
